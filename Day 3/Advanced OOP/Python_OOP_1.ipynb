# %% [markdown]
# ## All about oop
#  - Class
#      - Class attributes
#      - Class methods
#
# - Encapsulation
# - Inheritance
# - Polymorphism
# - Class association and object interaction

# %% [markdown]
# # Object Oriented Programming
# Python supports many different kinds of data <br>
# e.g., 12343.14159 "Hello" [1, 5, 7, 11, 13] <br>
#  {"CA": "California", "MA": "Massachusetts"}
# - each is an object, and every object has:
#     - a type
#     - an internal data representation(primitive or composite)
#     - a set of procedures for interactionwith the object
# - an object is an instanceof a type
#     - 1234 is an instance of an int
#     - "hello"is an instance of a string <br>

# %%
cities = {"CA": "California", "MA": "Massachusetts"}
print(type(cities))
# Out:
# <class 'dict'>

# %% [markdown]
# ## Class
# - Living Things, Non- Living things
# - Living - Plants, Animals
# - Animals - 4 Legged (Elephant), 2 Legged (Person)
# - Person - attributes : name, age, height; behaviours - move, talk, walk, eat [methods], calcTotal

# %%
# procedural
def calcTotal(alist):
    total = 0
    for i in alist:
        total = total +i
    print(total)

nums = [10,14,21]
calcTotal(nums)
# Out:
# 45

# %% [markdown]
# <b>EVERYTHING IN PYTHON IS AN OBJECT(and has a type)</b> <br>

# %% [markdown]
# ## What is an object?
# - a data abstraction, which really is a bundle of code. An object has both:
#     - internal representation through attributes
#     - interface to interact with the object through methods

# %% [markdown]
# Person - various attributes; methods
# John - object

# %% [markdown]
# ## Native objects in Python
# Let's consider a list

# %%
L = [1, 2, 3, 4]

# %% [markdown]
# ## Internal representation
# ![Screenshot%202020-06-10%20at%2019.23.16.png](attachment:Screenshot%202020-06-10%20at%2019.23.16.png)
# - linked list - follow a pointer from one cell to the next

# %% [markdown]
# ## Interface to manipulate a list
# - methods such as insert(), append(), len(), len(), min(), max(), del(L[i]), L.append(),L.extend(),L.count(),L.index(), L.insert(),L.pop(),L.remove(),L.reverse(), L.sort()

# %%
L[0]
# Out:
# 1

# %%
L.append(10)
L
# Out:
# [1, 2, 3, 4, 10, 10]

# %%
L.append("Python")
L
# Out:
# [1, 2, 3, 4, 10, 10, 'Python']

# %% [markdown]
# ## Important
# - internal representation should be private
# - correct behavior may be compromised if you manipulate internal representation directly <br>
# <b> We will cover this in more detail as part of Data Hiding</b>

# %% [markdown]
# - Encapsulation - putting together variable/attributes and the methods in one construct (class)
# - Cohesive design -
# - Data hiding
# - Attribute - private, public

# %% [markdown]
# ## Why OOP is popular
# - tends to resonate with our understanding of natural world
# - bundle data into packages together with procedures that work on them through well-defined interfaces
# - <b>divide-and-conquerdevelopment</b>
#     - implement and test behavior of each class separately
#     - increased modularity reduces complexity
# - classes make it easy to reuse code
#
# - inheritance allows subclasses to redefine or extend a selected subset of a superclass’ behavior

# %% [markdown]
# ## CREATING AND USING YOUR OWN TYPES WITH CLASSES
# There is a distinction between creating a class and using an instance of the class <br>
# - creating the class involves
#     - defining the class name
#     - defining class attributes
#     - defining instance variables
# - Example - someone wrote code to implement a list
#     - using the class involves
#         - creating new instances of objects
#         - doing operations on the instances

# %% [markdown]
# ## Defining your own class
# We define our own class using the <b> class </b> keyword <br>
# Let's define a coordinate class:

# %%
class Coordinate:
    a = 10
    #'A coordinate made up of an x and y value'
    def __init__(self, x, y): # constructor 
        # "Sets the x and y values"
        self.x =  x
        self.y = y
        
    def __str__(self): # toString()
        #'Returns a string representation of self'
        return "<" + str(self.x) + "," + str(self.y) + ">"
    def distance(self, other):
       # 'Returns the euclidean distance between two points'
        x_diff_sq = (self.x-other.x)**2
        y_diff_sq = (self.y-other.y)**2
        return (x_diff_sq + y_diff_sq)**0.5


c = Coordinate(2,5)
d = Coordinate(3,6)
c.distance(d)
# Out:
# 1.4142135623730951

# %%
class Coordinate2:
    def __init__(self, x, y):
        self.x = x
        self.y = y
    #def __str__(self):
        #'Returns a string representation of self'
       # return "<" + str(self.x) + "," + str(self.y) + ">"
    def distance(self, other):
        """ Returns the euclidean distance between two points """
        x_diff_sq = (self.x-other.x)**2
        y_diff_sq = (self.y-other.y)**2
        return (x_diff_sq + y_diff_sq)**0.5

# %%
c2 = Coordinate2(2,3)

# %% [markdown]
# ## What have we just done?
# - specificied a class called Coordinate
# - our Coordinate class has two attributes, x and y
# - we have defined two special methods:
#     - the constructor __init__ with two parameters
#     - the __str__ that represents the value of x and y
# - we have an instance method also, <b>distance</b> <br>
#
# Now let's use our class below:

# %%
c = Coordinate(3,4) # c is a coordinate object
origin = Coordinate(0,0) # origin is also a coordinate object

#print(c.x, origin.x)
#print(c.distance(origin))
#print(Coordinate.distance(c, origin)) # what is happening here
#print(origin.distance(c))
print(c)
# Out:
# <3,4>

# %% [markdown]
# ## Quick Review
# - What are the attributes in the Coordinate class?
# - What are the methods in the Coordinate class?

# %% [markdown]
# ## HOW TO CREATE AN INSTANCE OF A CLASS
# - We should specify  how to create an instance of our class
# - we use the special method (Constructor) __init__ to initialize some data attributes

# %%
Staff -  company, role
Student -  college
# implementation, design, analysis
Person - name, address, age

# %%
class Coordinate(object): # we get our coordinate class to inherit object class
    def __init__(self, x, y):
        self.x= x
        self.y= y
        
# x and y in __init__() are the parameters that are used to initialise class attributes
# self.x and self.y are the fields, or attributes of Coordinate 
# self - this is a parameter to refer to an instance of the class

# an object's state

# %% [markdown]
# ## Instance creation - again
# ![Screenshot%202020-06-10%20at%2020.07.22.png](attachment:Screenshot%202020-06-10%20at%2020.07.22.png)
# - data attributes of an instance are called instance variables
# - you do not provide argument for <b>self</b> in instatiating the object, Python does this automatically

# %% [markdown]
# ## What is a method?
# - it is a function that works only with this class
# - Python always passes the object as the first argument
#     - self is passed as the first argument of all methods
# - the <b>"."</b> operator is used to access any attribute
#     - a data attribute of an object
#     - a method of an object

# %%
# method, function, procedure
#- function 

def square(a):
    return a**2

def sqA(a):
    print(a**2)

# %%
c = Coordinate(3,4)
origin = Coordinate(0,0)
c.distance(origin) ## same as below
Coordinate.distance(c, origin)
# Out:
# 5.0

# %% [markdown]
# ## Printing an object representation
# - if we comment out the __str__() method, and run the code that follows:

# %%
class Coordinate(object):
    """ A coordinate made up of an x and y value """
    def __init__(self, x, y):
        """ Sets the x and y values """
        self.x = x
        self.y = y
    #def __str__(self):
        """ Returns a string representation of self """
        # return "<" + str(self.x) + "," + str(self.y) + ">"
    def distance(self, other):
        """ Returns the euclidean distance between two points """
        x_diff_sq = (self.x-other.x)**2
        y_diff_sq = (self.y-other.y)**2
        return (x_diff_sq + y_diff_sq)**0.5

# %%
c = Coordinate(3,4) 
print(c)

# %% [markdown]
# - the output is a memory address of object c
# - the __str__() method helps to print out something more relevant
# - Python calls the __str__ method when used with print on your class object
# ![Screenshot%202020-06-10%20at%2020.23.11.png](attachment:Screenshot%202020-06-10%20at%2020.23.11.png)

# %% [markdown]
# ## Summary
# - everything in Python is an object
# - everything inherits from Object class
# - A class is a container of data variables and methods

# %% [markdown]
# ### Attempt Task 1 in the `OOP Activity` file
