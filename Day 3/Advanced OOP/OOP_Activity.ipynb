# %% [markdown]
# ### Task 1: Simulating operations on a bank account
# Create a class named `BankAccount` to represent a bank account with functionalities for deposits, withdrawals, and displaying the current balance.
#
# **Instructions:**
#
# **1. Define the Class:**
# - Create a class named BankAccount using the `class` keyword.
# - Initialize the class with an __init__ method that takes the initial balance (balance) as a parameter.
# - Inside the __init__ method, assign the balance parameter to an attribute named self.balance.
#
# **2. Deposit Functionality:**
# - Create a method named deposit that takes an amount (amount) as a parameter.
# - Inside the deposit method, add the amount to the self.balance attribute.
#
# **3. Withdrawal Functionality:**
# - Create a method named withdraw that takes an amount (amount) as a parameter.
# - Inside the withdraw method, check if the amount is greater than the current self.balance.
#     - If the amount is greater, print a message indicating insufficient funds.
#     - If the amount is less than or equal to the balance, subtract the amount from self.balance.
#
# **4. Check Balance:**
# - Create a method named get_balance that doesn't take any arguments.
# - Inside the get_balance method, simply return the value of self.balance.
#
# **5. Test the BankAccount:**
# - Create an instance (object) of BankAccount with an initial balance of 100 (e.g., `account1 = BankAccount(100)`).
# - Call the deposit method on the account object with an amount of 50 (e.g., `account1.deposit(50)`).
# - Call the withdraw method on the account object with an amount of 75 (e.g., `account1.withdraw(75)`).
# - Call the get_balance method on the account object and print the returned value to see the updated balance.

# %%
# solve Task 1 here - add more cells if need be

# %% [markdown]
# ### Task 2
#
# A car owner has a name with 3 main attributes - first name, middle name and surname.
#
# The properties of a car are shown below and are tank size, miles per gallon, and model.
#
# Consider the following classes:
#
# ![image.png](attachment:image.png)
#
#
#
# Assume one Name object can have multiple car objects.
#
# - Supply all the setter and getter methods.
#
# - Implement one parameterised constructor of each class.
#
# - Compute estimated distance as `tanksize*manfMPG*GPL`. GPL is a constant value that you can assign.
# - Implement the tank bigger method of Car  so that it determines whether the size of the car’s tank is bigger than a specified value
# - Find out who the owner is by implementing getOwner() method in Car
#
#
# Since 1 Name object can have multiple cars, write some code that demonstrates that you can obtain the 3rd car of a given name object.

# %%
# Solve Task 2 here; add more cells if need be

# %% [markdown]
# ### Task 3 - Inheritance

# %% [markdown]
# #### Consider the following scenario and the provided UML class diagram
#  A charity shop has 2 categories of people who work there – Employees and Volunteers. Employees are identified by an Employee ID, e.g., MF1, ET2, etc. They receive a monthly salary. They all work 20 days per month. <br>
# Volunteers are identified by a Volunteer ID, an integer in the range 100-999. The number of days that they work each month varies. They are not paid a salary.
# The charity would like an application to keep details such as id, name, email and phone number, and determine how many hours are worked in total each month.
# The class diagram for both Volunteer and Employee, separately:
# ![Screenshot%202020-06-14%20at%2015.57.26.png](attachment:Screenshot%202020-06-14%20at%2015.57.26.png)

# %% [markdown]
# #### Refactoring the design
# NB: Setters are left out in the above classes due to space.
# We now refactor the design to apply inheritance
# ![Screenshot%202020-06-14%20at%2015.55.54.png](attachment:Screenshot%202020-06-14%20at%2015.55.54.png)
# What you are to do:
# - Implement the refactored design using Python.
# - Ensure the constructors have the following structure:
#     - Person class constructor - to have parameters for Name object, email, and phone.
#         - implement getters and setters
#     - Volunteer class constructor - to have parameters for vID, email, phone, hours, and Name object
#         - implement getters and setters for these parameters
#     - Employee class constructor - to have parameters for Name object, email, phone, salary, and eID
#         - implement getters and setters for these parameters
# - Ensure Employee Inherits Person, and Volunteer also inherits Person
# - Finally, test your application by:
#     - creating 1 volunteer object, 1 employee objects, 1 person object.
#     - place them in a list and use a loop to return the value of a property, e.g., firstname or something else<br>
# <b>NB: You will need to create a Name class with appropriate attributes (firstname, surname) and getters and setters</b>

# %%
# Solve Task 3 here - add more cells as you may need

# %% [markdown]
# ### Task 4: Abstract classes and methods
#
# **Scenario:**
#
# Design a parent class `Shape` with a subclass `Square` that inherits from it. The Shape
# class should have an abstract method `to calculate` area, and the Square class should
# implement this method to calculate the area of a square.
#
# **Instructions:**
# 1. Abstract Shape Class:
# - Create an abstract class named Shape using the abc module (from abc import ABC, abstractmethod).
# - Define an abstract method named calculate_area inside the Shape class using the `@abstractmethod` decorator. This method shouldn't have a body (pass).
# 2. Square Subclass:
# - Create a class named Square that inherits from the Shape class using the class Square(Shape): syntax.
# - Define an __init__ method in the Square class that takes the side length (side_length) as a parameter.
# - Inside the __init__ method, assign the side_length parameter to an attribute named self.side_length.
# 3. Implementing calculate_area in Square:
# - Override the calculate_area method inherited from the Shape class in the Square class.
# - Inside the overridden calculate_area method, calculate the area of the square by squaring the self.side_length and return the result.
#
# 4. Testing the Square Class:
# - Create an instance (object) of Square with a side length of 5 (e.g., square1 = Square(5)).
# - Call the calculate_area method on the square1 object and print the returned value. This should represent the area of the square.

# %%
# Solve Task 4 here - add more cells if need be
