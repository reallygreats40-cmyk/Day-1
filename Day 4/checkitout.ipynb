# %%
import numpy as np

array1 = np.random.randint(5, 10, size=1_000_000)
array1
# Out:
# array([5, 8, 9, ..., 5, 8, 7])

# %%
# %timeit np.sum(array1)
# %timeit sum(array1)
# Out:
# 70.4 μs ± 428 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 23.6 ms ± 422 μs per loop (mean ± std. dev. of 7 runs, 10 loops each)
