# %% [markdown]
# # Task - on Merging Datasets

# %% [markdown]
# ### Introduction:
#
# The data is in two csv files, cars1 and cars2.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Grab the data and upload it to be accessed.

# %%
# ignore if not using Google Colab
from google.colab import files
f = files.upload()
# Out:
#      <input type="file" id="files-69c1b040-f485-4868-be2f-ae79ac0f7ac5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-69c1b040-f485-4868-be2f-ae79ac0f7ac5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cars1.csv to cars1.csv
# Saving cars2.csv to cars2.csv

# %% [markdown]
#    ### Step 3. Assign each to a to a variable called cars1 and cars2

# %%
cars1 = pd.read_csv("cars1.csv")
cars2 = pd.read_csv("cars2.csv")

cars2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           200 non-null    float64
#  1   cylinders     200 non-null    int64
#  2   displacement  200 non-null    int64
#  3   horsepower    200 non-null    object
#  4   weight        200 non-null    int64
#  5   acceleration  200 non-null    float64
#  6   model         200 non-null    int64
#  7   origin        200 non-null    int64
#  8   car           200 non-null    object
# dtypes: float64(2), int64(5), object(2)
# memory usage: 14.2+ KB

# %%
cars2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           200 non-null    float64
#  1   cylinders     200 non-null    int64
#  2   displacement  200 non-null    int64
#  3   horsepower    200 non-null    object
#  4   weight        200 non-null    int64
#  5   acceleration  200 non-null    float64
#  6   model         200 non-null    int64
#  7   origin        200 non-null    int64
#  8   car           200 non-null    object
# dtypes: float64(2), int64(5), object(2)
# memory usage: 14.2+ KB

# %%
cars1.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0       1  chevrolet chevelle malibu         NaN          NaN          NaN
# 1       1          buick skylark 320         NaN          NaN          NaN
# 2       1         plymouth satellite         NaN          NaN          NaN
# 3       1              amc rebel sst         NaN          NaN          NaN
# 4       1                ford torino         NaN          NaN          NaN
#
#    Unnamed: 12  Unnamed: 13
# 0          NaN          NaN
# ...

# %% [markdown]
# ### Step 4. Fixing unnamed columns by slicing cars1

# %%
cars1 = cars1.loc[:, "mpg":"car"]
cars1.head()


#cars1=cars1.dropna(axis=1, how='all')

cars1.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %% [markdown]
# ### Step 5. What is the number of observations in each dataset?

# %%
#cars1.info()
len(cars1)
cars1.shape[0]
# Out:
# 198

# %%
print(cars1.shape[0])
print(cars2.shape[0])
# Out:
# 198
# 200

# %% [markdown]
# ### Step 6. Join cars1 and cars2 into a single DataFrame called cars

# %%
cars_list = [cars1, cars2]
cars = pd.concat(cars_list) # or see below
cars.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
c = pd.concat([cars1,cars2])
c.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
cars.shape[0]
# Out:
# 398

# %% [markdown]
# ### Step 7. There is a column missing, called `owners`.
# - Create random numbers whose size shou1d be between 5,000 to 73,000. Create numbers equal to the amount of records in `cars` dataframe.

# %%
nr_owners = np.random.randint(15000, high=73000, size= cars.shape[0])
nr_owners
# Out:
# array([68820, 58341, 19305, 49286, 56993, 70103, 32206, 34968, 18369,
#        63488, 38354, 16009, 69281, 41435, 21034, 59977, 55582, 17037,
#        18613, 65713, 25023, 59740, 39188, 50858, 17210, 25024, 38967,
#        67375, 16471, 39054, 16180, 60609, 60439, 37137, 40955, 60552,
#        43098, 55400, 56993, 43459, 66598, 66733, 32992, 33388, 20706,
#        56153, 20742, 24991, 55721, 18271, 43328, 62068, 47137, 68922,
#        41102, 24563, 51639, 35806, 64455, 32965, 69719, 20557, 53601,
#        70251, 51218, 20285, 26308, 45732, 17221, 42215, 62745, 40217,
#        36889, 51924, 35268, 22782, 67146, 22304, 32730, 72732, 37137,
#        26001, 39030, 32465, 47401, 54057, 63044, 15041, 19649, 27179,
#        44223, 26977, 24168, 31443, 51088, 57767, 21551, 32136, 47978,
#        51359, 31579, 55468, 52816, 56263, 37957, 56206, 16282, 46075,
#        57333, 50905, 27982, 45437, 38668, 47097, 26422, 64515, 50891,
# ...

# %%
nr_owners.size
# Out:
# 398

# %% [markdown]
# ### Step 8. Add the column owners to cars
# - the `owners` column should have the values of `nr_onwers`

# %%
cars['owners'] = nr_owners
cars.reset_index()
cars.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car  owners
# 0       1  chevrolet chevelle malibu   68820
# 1       1          buick skylark 320   58341
# 2       1         plymouth satellite   19305
# 3       1              amc rebel sst   49286
# 4       1                ford torino   56993
